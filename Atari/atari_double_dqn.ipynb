# %%
import pandas as pd
import numpy as np
import unicodedata
import string
import re
import random
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from collections import Counter
import pickle
import random
import pdb
from torch.utils.data import DataLoader
import logging
import itertools
import unicodedata
import string
import re
import random
import argparse
from torch import optim
import time
import os
from torch.utils.data import BatchSampler
from torch.utils.data import SequentialSampler
from torch.utils.data import Sampler
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
import math
import copy
import seaborn
import datetime
from logger import Logger

from torch.optim import RMSprop
import shutil
from statistics import mean

from gym_wrappers import MainGymWrapper
import gym
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
device = torch.device('cpu')

# %%
class ConvolutionalNeuralNetwork(nn.Module):
    def __init__(self, input_shape, action_space):
        super(ConvolutionalNeuralNetwork, self).__init__()
        self.input_shape = input_shape
        self.action_space = action_space
        self.conv1 = nn.Conv2d(in_channels=input_shape[0], out_channels=32, kernel_size=8, stride=(4,4))
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64,kernel_size=4,stride=(2,2))
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3)
        
        o_size = 3136
        self.linear1 = nn.Linear(in_features=o_size, out_features=512)
        self.linear2 = nn.Linear(in_features=512, out_features=self.action_space)
        
    def forward(self, x, batch_size=None):
        x = torch.from_numpy(x).float().to(device)
#         print(x.size(), torch.Size([1, 4, 84, 84]))
        out = F.relu(self.conv1(x))
        out = F.relu(self.conv2(out))
        out = F.relu(self.conv3(out))

        # out = (bs, nc, x, y)
        if batch_size==None:
            batch_size = out.size(0)
#         print(out.size())
        out_flat = out.view(batch_size, -1)
        
        out_flat = F.relu(self.linear1(out_flat))
        
        out_flat = self.linear2(out_flat)
        return out_flat

# %%
game_name = "Breakout-v0"
game_mode = 'ddqn_training'
render = False
total_step_limit = 5000000
total_run_limit = None
clip = True

FRAMES_IN_OBSERVATION = 4
FRAME_SIZE = 84
INPUT_SHAPE = (FRAMES_IN_OBSERVATION, FRAME_SIZE, FRAME_SIZE)

# %%
env_name = game_name + "Deterministic-v4" 
game_name, env_name
# Out:
# ('Breakout-v0', 'Breakout-v0Deterministic-v4')

# %%
env = MainGymWrapper.wrap(gym.make(game_name))
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
GAMMA = 0.99
MEMORY_SIZE = 900000
BATCH_SIZE = 32
TRAINING_FREQUENCY = 4
TARGET_NETWORK_UPDATE_FREQUENCY = 40000
MODEL_PERSISTENCE_UPDATE_FREQUENCY = 10000
REPLAY_START_SIZE = 50000

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.1
EXPLORATION_TEST = 0.02
EXPLORATION_STEPS = 850000
EXPLORATION_DECAY = (EXPLORATION_MAX-EXPLORATION_MIN)/EXPLORATION_STEPS

# %%
class DDQNTrainer:
    def __init__(self, game_name, input_shape, action_space):
        
        self.input_shape = input_shape
        self.game_name = game_name
        self.action_space = action_space
        
        self.game_mode = "DDQN training"
        self.model_path = "/scratch/cvh255/atari/output/neural_nets/" + game_name + "/actual_ddqn/" + self._get_date() + "/model.h5"
#         self.model_path
        self.logger_path = "/scratch/cvh255/atari/output/logs/" + game_name + "/actual_ddqn/training/" + self._get_date() + "/"
        self.logger = Logger(self.game_name + " " + self.game_mode, self.logger_path)
        
        if os.path.exists(os.path.dirname(self.model_path)):
            shutil.rmtree(os.path.dirname(self.model_path), ignore_errors=True)
        os.makedirs(os.path.dirname(self.model_path))

        self.ddqn = ConvolutionalNeuralNetwork(self.input_shape, action_space).to(device)
        
        self.criteria = nn.MSELoss()
        self.optimizer = RMSprop(self.ddqn.parameters(), lr=0.00025, alpha = 0.95, eps=0.01)
        
        if os.path.isfile(self.model_path):
#             self.ddqn.load_state_dict(torch.load(self.model_path))
            self.ddqn.load_state_dictict(torch.load("/home/cvh255/atari_game/output/neural_nets/Breakout-v0try4/actual_ddqn/2019-05-07/model.h5"))
        
        self.ddqn_target = ConvolutionalNeuralNetwork(self.input_shape, action_space).to(device)
#         .model
        self._reset_target_network()
        self.epsilon = EXPLORATION_MAX
        self.memory = []
    
    def _save_model(self):
        torch.save(self.ddqn.state_dict(),self.model_path)
        
    def _get_date(self):
        return str(datetime.datetime.now().strftime('%Y-%m-%d'))
        
    def save_run(self, score, step, run):
        self.logger.add_score(score)
        self.logger.add_step(step)
        self.logger.add_run(run)

    def move(self, state):
        if np.random.rand() < self.epsilon or len(self.memory) < REPLAY_START_SIZE:
            return random.randrange(self.action_space)
        
        q_values = self.ddqn(np.expand_dims(np.asarray(state).astype(np.float64), axis=0), batch_size=1)
        return np.argmax(q_values[0].detach().cpu().numpy())

    def remember(self, current_state, action, reward, next_state, terminal):
        self.memory.append({"current_state": current_state,
                            "action": action,
                            "reward": reward,
                            "next_state": next_state,
                            "terminal": terminal})
        if len(self.memory) > MEMORY_SIZE:
            self.memory.pop(0)

    def step_update(self, total_step):
        if len(self.memory) < REPLAY_START_SIZE:
            return

        if total_step % TRAINING_FREQUENCY == 0:
            loss, accuracy, average_max_q = self._train()
            self.logger.add_loss(loss.item())
            self.logger.add_accuracy(accuracy)
            self.logger.add_q(average_max_q)

        self._update_epsilon()

        if total_step % MODEL_PERSISTENCE_UPDATE_FREQUENCY == 0:
            self._save_model()

        if total_step % TARGET_NETWORK_UPDATE_FREQUENCY == 0:
            self._reset_target_network()
            print('{{"metric": "epsilon", "value": {}}}'.format(self.epsilon))
            print('{{"metric": "total_step", "value": {}}}'.format(total_step))

    def _train(self):
        
        self.optimizer.zero_grad()
        self.ddqn_target.eval()
        batch = np.asarray(random.sample(self.memory, BATCH_SIZE))
        if len(batch) < BATCH_SIZE:
            return

        current_states = []
        actions = []
        rewards = []
        next_states = []
        terminals = []
        
        for entry in batch:
            current_state = np.expand_dims(np.asarray(entry["current_state"]).astype(np.float64), axis=0)
            current_states.append(current_state)
            
            next_state = np.expand_dims(np.asarray(entry["next_state"]).astype(np.float64), axis=0)
            next_states.append(next_state)
            
            rewards.append(entry['reward'])
            actions.append(entry['action'])
            terminals.append(entry['terminal'])
            
        non_final_mask = torch.tensor(terminals)==False
        non_final_next_states = np.asarray(next_states).squeeze()
        
        state_batch = np.asarray(current_states).squeeze()
        action_batch = np.asanyarray(actions).squeeze()
        reward_batch = np.asarray(rewards).squeeze() 
        
        state_action_values = self.ddqn(state_batch).gather(1, torch.from_numpy(action_batch).unsqueeze(dim=1).to(device))
        ddqn_next_state_out = self.ddqn(non_final_next_states)
        ddqn_next_actions = torch.argmax(ddqn_next_state_out, dim=1)
        
#         print(ddqn_next_actions.size(), 32)
        
        next_state_values = np.zeros(BATCH_SIZE)
        temp = self.ddqn_target(non_final_next_states).gather(1, ddqn_next_actions.unsqueeze(dim=1).to(device)).squeeze().detach().cpu().numpy()
#         print("tem var",temp.shape, 32)
        
        next_state_values[list(np.array(terminals)==False)] = temp[list(np.array(terminals)==False)]
        expected_state_action_values = (next_state_values * GAMMA) + reward_batch
        
#         loss = self.criteria(state_action_values, torch.from_numpy(expected_state_action_values).unsqueeze(1))
        loss = F.smooth_l1_loss(state_action_values, torch.from_numpy(expected_state_action_values).unsqueeze(1).to(device).float())
        loss.backward()
        
        for param in self.ddqn.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()
        
#         print(torch.from_numpy(action_batch).unsqueeze(dim=1).size(),torch.Size([32, 1]))
#         print(state_action_values.size(),[32, 4])
#         print(state_action_values.size(),torch.Size([32, 1]))
#         print(non_final_next_states.squeeze().size(), torch.Size([32, 4, 84, 84]))
        
        accuracy = 0
        return loss, accuracy, mean(expected_state_action_values)

    def _update_epsilon(self):
        self.epsilon -= EXPLORATION_DECAY
        self.epsilon = max(EXPLORATION_MIN, self.epsilon)

    def _reset_target_network(self):
        self.ddqn_target.load_state_dict(self.ddqn.state_dict())

# %%
def main_loop(game_model, env, render, total_step_limit, total_run_limit, clip):
    run = 0
    total_step = 0
    while True:
        if run%10==0:
            print('-'*100)
            print("RUN = ",run)
        if total_run_limit is not None and run >= total_run_limit:
            print("Reached total run limit of: " + str(total_run_limit))
            exit(0)

        run += 1
        current_state = env.reset()
        step = 0
        score = 0

        while True:
            if total_step >= total_step_limit:
                print("Reached total step limit of: " + str(total_step_limit))
                exit(0)
            total_step += 1
            
            step += 1

            if render:
                env.render()

            action = game_model.move(current_state)
            next_state, reward, terminal, info = env.step(action)
            if clip:
                np.sign(reward)
            score += reward
            game_model.remember(current_state, action, reward, next_state, terminal)
            current_state = next_state

            game_model.step_update(total_step)

            if terminal:
                game_model.save_run(score, step, run)
                break

# %%
game_model = DDQNTrainer(game_name+"try5", INPUT_SHAPE, env.action_space.n)
main_loop(game_model, env, render, total_step_limit, total_run_limit, clip)
# Out:
# score: (min: 0.0, avg: 1.0, max: 3.0
# {"metric": "score", "value": 1.0}
# step: (min: 173, avg: 232.4, max: 335
# {"metric": "step", "value": 232.4}
# {"metric": "run", "value": 970}
# ----------------------------------------------------------------------------------------------------
# RUN =  970
# {"metric": "epsilon", "value": 0.7988224705886545}
# {"metric": "total_step", "value": 240000}
# score: (min: 0.0, avg: 1.4, max: 3.0
# {"metric": "score", "value": 1.4}
# step: (min: 160, avg: 246.4, max: 343
# {"metric": "step", "value": 246.4}
# {"metric": "run", "value": 980}
# ----------------------------------------------------------------------------------------------------
# RUN =  980
# loss: (min: 4.964628897141665e-05, avg: 0.0029626009539933875, max: 0.028166385367512703
# {"metric": "loss", "value": 0.0029626009539933875}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.9249736624024808, avg: -0.8457670888779085, max: -0.6761511852359399
# {"metric": "q", "value": -0.8457670888779085}
# score: (min: 0.0, avg: 2.0, max: 3.0
# {"metric": "score", "value": 2.0}
# step: (min: 187, avg: 275.7, max: 338
# {"metric": "step", "value": 275.7}
# {"metric": "run", "value": 990}
# ----------------------------------------------------------------------------------------------------
# RUN =  990
# loss: (min: 6.922517059138045e-05, avg: 0.0025383286596770633, max: 0.02754788100719452
# {"metric": "loss", "value": 0.0025383286596770633}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8588292464800179, avg: -0.8090963383460045, max: -0.6953809525817632
# {"metric": "q", "value": -0.8090963383460045}
# score: (min: 0.0, avg: 0.7, max: 3.0
# {"metric": "score", "value": 0.7}
# step: (min: 163, avg: 220.7, max: 343
# {"metric": "step", "value": 220.7}
# {"metric": "run", "value": 1000}
# ----------------------------------------------------------------------------------------------------
# RUN =  1000
# score: (min: 0.0, avg: 0.9, max: 2.0
# {"metric": "score", "value": 0.9}
# step: (min: 160, avg: 221.1, max: 295
# {"metric": "step", "value": 221.1}
# {"metric": "run", "value": 1010}
# ----------------------------------------------------------------------------------------------------
# RUN =  1010
# loss: (min: 5.2220053476048633e-05, avg: 0.0025660471740302456, max: 0.024403288960456848
# {"metric": "loss", "value": 0.0025660471740302456}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8602103574760258, avg: -0.8085544759057703, max: -0.7029020970151759
# {"metric": "q", "value": -0.8085544759057703}
# score: (min: 0.0, avg: 1.4, max: 3.0
# {"metric": "score", "value": 1.4}
# step: (min: 163, avg: 248.4, max: 365
# {"metric": "step", "value": 248.4}
# {"metric": "run", "value": 1020}
# ----------------------------------------------------------------------------------------------------
# RUN =  1020
# score: (min: 0.0, avg: 2.4, max: 6.0
# {"metric": "score", "value": 2.4}
# step: (min: 157, avg: 285.1, max: 463
# {"metric": "step", "value": 285.1}
# {"metric": "run", "value": 1030}
# ----------------------------------------------------------------------------------------------------
# RUN =  1030
# loss: (min: 7.554993499070406e-05, avg: 0.002586129357718164, max: 0.02819882147014141
# {"metric": "loss", "value": 0.002586129357718164}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8612006397731602, avg: -0.8086839460067602, max: -0.7169554268126376
# {"metric": "q", "value": -0.8086839460067602}
# score: (min: 0.0, avg: 1.6, max: 4.0
# {"metric": "score", "value": 1.6}
# step: (min: 164, avg: 256.4, max: 420
# {"metric": "step", "value": 256.4}
# {"metric": "run", "value": 1040}
# ----------------------------------------------------------------------------------------------------
# RUN =  1040
# loss: (min: 6.872505036881194e-05, avg: 0.002484739137282304, max: 0.03452666848897934
# {"metric": "loss", "value": 0.002484739137282304}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.861056968588382, avg: -0.8096118306716613, max: -0.7036432370869443
# {"metric": "q", "value": -0.8096118306716613}
# score: (min: 0.0, avg: 2.2, max: 8.0
# {"metric": "score", "value": 2.2}
# step: (min: 173, avg: 268.8, max: 432
# {"metric": "step", "value": 268.8}
# {"metric": "run", "value": 1050}
# ----------------------------------------------------------------------------------------------------
# RUN =  1050
# score: (min: 0.0, avg: 1.2, max: 3.0
# {"metric": "score", "value": 1.2}
# step: (min: 164, avg: 239.2, max: 323
# {"metric": "step", "value": 239.2}
# {"metric": "run", "value": 1060}
# ----------------------------------------------------------------------------------------------------
# RUN =  1060
# loss: (min: 6.757868686690927e-05, avg: 0.0026141808029206005, max: 0.10927318781614304
# {"metric": "loss", "value": 0.0026141808029206005}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8598353025130928, avg: -0.8077236878322734, max: -0.6435731021675747
# {"metric": "q", "value": -0.8077236878322734}
# score: (min: 0.0, avg: 2.6, max: 5.0
# {"metric": "score", "value": 2.6}
# step: (min: 171, avg: 306.7, max: 435
# {"metric": "step", "value": 306.7}
# {"metric": "run", "value": 1070}
# ----------------------------------------------------------------------------------------------------
# RUN =  1070
# loss: (min: 5.3174015192780644e-05, avg: 0.002366367907001404, max: 0.023766539990901947
# {"metric": "loss", "value": 0.002366367907001404}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8574574588425458, avg: -0.8075964776373116, max: -0.6950523143354803
# {"metric": "q", "value": -0.8075964776373116}
# score: (min: 0.0, avg: 1.1, max: 2.0
# {"metric": "score", "value": 1.1}
# step: (min: 176, avg: 233.3, max: 287
# {"metric": "step", "value": 233.3}
# {"metric": "run", "value": 1080}
# ----------------------------------------------------------------------------------------------------
# RUN =  1080
# score: (min: 1.0, avg: 1.6, max: 3.0
# {"metric": "score", "value": 1.6}
# step: (min: 219, avg: 262.5, max: 350
# {"metric": "step", "value": 262.5}
# {"metric": "run", "value": 1090}
# ----------------------------------------------------------------------------------------------------
# RUN =  1090
# loss: (min: 5.7137054682243615e-05, avg: 0.00241099571261293, max: 0.10860123485326767
# {"metric": "loss", "value": 0.00241099571261293}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.865434141587466, avg: -0.8099229009249591, max: -0.6467137282341718
# {"metric": "q", "value": -0.8099229009249591}
# score: (min: 0.0, avg: 1.7, max: 3.0
# {"metric": "score", "value": 1.7}
# step: (min: 167, avg: 263, max: 335
# {"metric": "step", "value": 263}
# {"metric": "run", "value": 1100}
# ----------------------------------------------------------------------------------------------------
# RUN =  1100
# loss: (min: 4.551548045128584e-05, avg: 0.002455051191340317, max: 0.024204475805163383
# {"metric": "loss", "value": 0.002455051191340317}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8624196043610572, avg: -0.8085016958599747, max: -0.6840861620404758
# {"metric": "q", "value": -0.8085016958599747}
# score: (min: 0.0, avg: 2.1, max: 5.0
# {"metric": "score", "value": 2.1}
# step: (min: 178, avg: 292.3, max: 497
# {"metric": "step", "value": 292.3}
# {"metric": "run", "value": 1110}
# ----------------------------------------------------------------------------------------------------
# RUN =  1110
# score: (min: 0.0, avg: 1.8, max: 5.0
# {"metric": "score", "value": 1.8}
# step: (min: 175, avg: 271.5, max: 457
# {"metric": "step", "value": 271.5}
# {"metric": "run", "value": 1120}
# ----------------------------------------------------------------------------------------------------
# RUN =  1120
# loss: (min: 4.175350477453321e-05, avg: 0.002322232898197399, max: 0.025846663862466812
# {"metric": "loss", "value": 0.002322232898197399}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8619508418999612, avg: -0.8079157768272719, max: -0.6986419118754565
# {"metric": "q", "value": -0.8079157768272719}
# {"metric": "epsilon", "value": 0.7564695294122722}
# {"metric": "total_step", "value": 280000}
# score: (min: 0.0, avg: 1.3, max: 6.0
# {"metric": "score", "value": 1.3}
# step: (min: 165, avg: 249.3, max: 482
# {"metric": "step", "value": 249.3}
# {"metric": "run", "value": 1130}
# ----------------------------------------------------------------------------------------------------
# RUN =  1130
# loss: (min: 6.408766057575122e-05, avg: 0.0026165249912664876, max: 0.026092980057001114
# {"metric": "loss", "value": 0.0026165249912664876}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.871669497191906, avg: -0.8069761442748533, max: -0.6689297364838421
# {"metric": "q", "value": -0.8069761442748533}
# score: (min: 0.0, avg: 2.4, max: 6.0
# {"metric": "score", "value": 2.4}
# step: (min: 188, avg: 300.1, max: 498
# {"metric": "step", "value": 300.1}
# {"metric": "run", "value": 1140}
# ----------------------------------------------------------------------------------------------------
# RUN =  1140
# loss: (min: 6.83659891365096e-05, avg: 0.002291020263437531, max: 0.028078695759177208
# {"metric": "loss", "value": 0.002291020263437531}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8725633114948869, avg: -0.8075626170643914, max: -0.6862822065013461
# {"metric": "q", "value": -0.8075626170643914}
# score: (min: 0.0, avg: 2.0, max: 5.0
# {"metric": "score", "value": 2.0}
# step: (min: 175, avg: 274.5, max: 439
# {"metric": "step", "value": 274.5}
# {"metric": "run", "value": 1150}
# ----------------------------------------------------------------------------------------------------
# RUN =  1150
# score: (min: 0.0, avg: 1.3, max: 5.0
# {"metric": "score", "value": 1.3}
# step: (min: 173, avg: 256, max: 496
# {"metric": "step", "value": 256}
# {"metric": "run", "value": 1160}
# ----------------------------------------------------------------------------------------------------
# RUN =  1160
# loss: (min: 8.407876885030419e-05, avg: 0.002129664418331231, max: 0.027805710211396217
# {"metric": "loss", "value": 0.002129664418331231}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8684870565310121, avg: -0.8078705095451575, max: -0.7025720327952877
# {"metric": "q", "value": -0.8078705095451575}
# score: (min: 0.0, avg: 1.6, max: 3.0
# {"metric": "score", "value": 1.6}
# step: (min: 167, avg: 259.1, max: 360
# {"metric": "step", "value": 259.1}
# {"metric": "run", "value": 1170}
# ----------------------------------------------------------------------------------------------------
# RUN =  1170
# score: (min: 0.0, avg: 1.1, max: 4.0
# {"metric": "score", "value": 1.1}
# step: (min: 160, avg: 226.9, max: 342
# {"metric": "step", "value": 226.9}
# {"metric": "run", "value": 1180}
# ----------------------------------------------------------------------------------------------------
# RUN =  1180
# loss: (min: 6.763248529750854e-05, avg: 0.0021275785932230065, max: 0.0283262487500906
# {"metric": "loss", "value": 0.0021275785932230065}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.8755818170495331, avg: -0.8076130832529644, max: -0.6703743038512766
# {"metric": "q", "value": -0.8076130832529644}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e0068cb1ebe4> in <module>()
#       1 game_model = DDQNTrainer(game_name+"try5", INPUT_SHAPE, env.action_space.n)
# ----> 2 main_loop(game_model, env, render, total_step_limit, total_run_limit, clip)
#
# <ipython-input-10-add6c24eec31> in main_loop(game_model, env, render, total_step_limit, total_run_limit, clip)
#      34             current_state = next_state
#      35
# ---> 36             game_model.step_update(total_step)
#      37
#      38             if terminal:
#
# <ipython-input-9-5b9ed416a132> in step_update(self, total_step)
#      63
#      64         if total_step % TRAINING_FREQUENCY == 0:
# ---> 65             loss, accuracy, average_max_q = self._train()
#      66             self.logger.add_loss(loss.item())
#      67             self.logger.add_accuracy(accuracy)
#
# <ipython-input-9-5b9ed416a132> in _train(self)
#     111
#     112         state_action_values = self.ddqn(state_batch).gather(1, torch.from_numpy(action_batch).unsqueeze(dim=1).to(device))
# --> 113         ddqn_next_state_out = self.ddqn(non_final_next_states)
#     114         ddqn_next_actions = torch.argmax(ddqn_next_state_out, dim=1)
#     115
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-3-747f4f1f9543> in forward(self, x, batch_size)
#      17         out = F.relu(self.conv1(x))
#      18         out = F.relu(self.conv2(out))
# ---> 19         out = F.relu(self.conv3(out))
#      20
#      21         # out = (bs, nc, x, y)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# KeyboardInterrupt:

# %%
game_model = DDQNTrainer(game_name+"try4", INPUT_SHAPE, env.action_space.n)
main_loop(game_model, env, render, total_step_limit, total_run_limit, clip)
# Out:
# ----------------------------------------------------------------------------------------------------
# RUN =  0
# /home/cvh255/pyenv/gym/gym/logger.py:30: UserWarning: WARN: <class 'gym_wrappers.NoopResetEnv'> doesn't implement 'step' method, which is required for wrappers derived directly from Wrapper. Deprecated default implementation is used.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# score: (min: 0.0, avg: 2.0, max: 9.0
# {"metric": "score", "value": 2.0}
# step: (min: 174, avg: 266.4, max: 532
# {"metric": "step", "value": 266.4}
# {"metric": "run", "value": 10}
# ----------------------------------------------------------------------------------------------------
# RUN =  10
# score: (min: 0.0, avg: 1.3, max: 4.0
# {"metric": "score", "value": 1.3}
# step: (min: 172, avg: 241.5, max: 348
# {"metric": "step", "value": 241.5}
# {"metric": "run", "value": 20}
# ----------------------------------------------------------------------------------------------------
# RUN =  20
# score: (min: 0.0, avg: 1.9, max: 4.0
# {"metric": "score", "value": 1.9}
# step: (min: 170, avg: 275.6, max: 378
# {"metric": "step", "value": 275.6}
# {"metric": "run", "value": 30}
# ----------------------------------------------------------------------------------------------------
# RUN =  30
# score: (min: 0.0, avg: 1.4, max: 4.0
# {"metric": "score", "value": 1.4}
# step: (min: 163, avg: 255.7, max: 420
# {"metric": "step", "value": 255.7}
# {"metric": "run", "value": 40}
# ----------------------------------------------------------------------------------------------------
# RUN =  40
# score: (min: 0.0, avg: 1.7, max: 8.0
# {"metric": "score", "value": 1.7}
# step: (min: 165, avg: 243.7, max: 420
# {"metric": "step", "value": 243.7}
# {"metric": "run", "value": 50}
# ----------------------------------------------------------------------------------------------------
# RUN =  50
# score: (min: 0.0, avg: 1.1, max: 3.0
# {"metric": "score", "value": 1.1}
# step: (min: 165, avg: 232.9, max: 346
# {"metric": "step", "value": 232.9}
# {"metric": "run", "value": 60}
# ----------------------------------------------------------------------------------------------------
# RUN =  60
# score: (min: 0.0, avg: 1.2, max: 3.0
# {"metric": "score", "value": 1.2}
# step: (min: 164, avg: 235, max: 308
# {"metric": "step", "value": 235}
# {"metric": "run", "value": 70}
# ----------------------------------------------------------------------------------------------------
# RUN =  70
# score: (min: 0.0, avg: 1.9, max: 4.0
# {"metric": "score", "value": 1.9}
# step: (min: 175, avg: 279.8, max: 381
# {"metric": "step", "value": 279.8}
# {"metric": "run", "value": 80}
# ----------------------------------------------------------------------------------------------------
# RUN =  80
# score: (min: 0.0, avg: 0.8, max: 2.0
# {"metric": "score", "value": 0.8}
# step: (min: 167, avg: 218.5, max: 294
# {"metric": "step", "value": 218.5}
# {"metric": "run", "value": 90}
# ----------------------------------------------------------------------------------------------------
# RUN =  90
# score: (min: 0.0, avg: 1.4, max: 5.0
# {"metric": "score", "value": 1.4}
# step: (min: 169, avg: 235.3, max: 398
# {"metric": "step", "value": 235.3}
# {"metric": "run", "value": 100}
# ----------------------------------------------------------------------------------------------------
# RUN =  100
# score: (min: 0.0, avg: 1.6, max: 4.0
# {"metric": "score", "value": 1.6}
# step: (min: 162, avg: 253.1, max: 356
# {"metric": "step", "value": 253.1}
# {"metric": "run", "value": 110}
# ----------------------------------------------------------------------------------------------------
# RUN =  110
# score: (min: 0.0, avg: 1.6, max: 4.0
# {"metric": "score", "value": 1.6}
# step: (min: 162, avg: 253.8, max: 408
# {"metric": "step", "value": 253.8}
# {"metric": "run", "value": 120}
# ----------------------------------------------------------------------------------------------------
# RUN =  120
# score: (min: 0.0, avg: 1.1, max: 2.0
# {"metric": "score", "value": 1.1}
# step: (min: 162, avg: 229.9, max: 303
# {"metric": "step", "value": 229.9}
# {"metric": "run", "value": 130}
# ----------------------------------------------------------------------------------------------------
# RUN =  130
# score: (min: 0.0, avg: 1.2, max: 3.0
# {"metric": "score", "value": 1.2}
# step: (min: 162, avg: 244.1, max: 363
# {"metric": "step", "value": 244.1}
# {"metric": "run", "value": 140}
# ----------------------------------------------------------------------------------------------------
# RUN =  140
# score: (min: 0.0, avg: 1.5, max: 4.0
# {"metric": "score", "value": 1.5}
# step: (min: 161, avg: 251.4, max: 387
# {"metric": "step", "value": 251.4}
# {"metric": "run", "value": 150}
# ----------------------------------------------------------------------------------------------------
# RUN =  150
# score: (min: 1.0, avg: 2.5, max: 6.0
# {"metric": "score", "value": 2.5}
# step: (min: 204, avg: 288.5, max: 433
# {"metric": "step", "value": 288.5}
# {"metric": "run", "value": 160}
# ----------------------------------------------------------------------------------------------------
# RUN =  160
# score: (min: 0.0, avg: 1.4, max: 3.0
# {"metric": "score", "value": 1.4}
# step: (min: 158, avg: 241.2, max: 289
# {"metric": "step", "value": 241.2}
# {"metric": "run", "value": 170}
# ----------------------------------------------------------------------------------------------------
# RUN =  170
# score: (min: 0.0, avg: 1.2, max: 4.0
# {"metric": "score", "value": 1.2}
# step: (min: 161, avg: 233.2, max: 400
# {"metric": "step", "value": 233.2}
# {"metric": "run", "value": 180}
# ----------------------------------------------------------------------------------------------------
# RUN =  180
# score: (min: 0.0, avg: 0.9, max: 5.0
# {"metric": "score", "value": 0.9}
# step: (min: 165, avg: 228.4, max: 454
# {"metric": "step", "value": 228.4}
# {"metric": "run", "value": 190}
# ----------------------------------------------------------------------------------------------------
# RUN =  190
# score: (min: 0.0, avg: 1.4, max: 4.0
# {"metric": "score", "value": 1.4}
# step: (min: 171, avg: 244.3, max: 400
# {"metric": "step", "value": 244.3}
# {"metric": "run", "value": 200}
# ----------------------------------------------------------------------------------------------------
# RUN =  200
# score: (min: 0.0, avg: 1.0, max: 2.0
# {"metric": "score", "value": 1.0}
# step: (min: 170, avg: 224, max: 280
# {"metric": "step", "value": 224}
# {"metric": "run", "value": 210}
# ----------------------------------------------------------------------------------------------------
# RUN =  210
# loss: (min: 0.0018251040019094944, avg: 0.769435632461682, max: 5
# {"metric": "loss", "value": 0.769435632461682}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -1.5863673453032971, avg: 0.16280615721066483, max: 2.739267724081874
# {"metric": "q", "value": 0.16280615721066483}
# score: (min: 0.0, avg: 1.9, max: 4.0
# {"metric": "score", "value": 1.9}
# step: (min: 153, avg: 273.8, max: 381
# {"metric": "step", "value": 273.8}
# {"metric": "run", "value": 220}
# ----------------------------------------------------------------------------------------------------
# RUN =  220
# score: (min: 0.0, avg: 1.4, max: 4.0
# {"metric": "score", "value": 1.4}
# step: (min: 163, avg: 235, max: 370
# {"metric": "step", "value": 235}
# {"metric": "run", "value": 230}
# ----------------------------------------------------------------------------------------------------
# RUN =  230
# loss: (min: 0.0011864565312862396, avg: 0.6599700596602633, max: 4.232838153839111
# {"metric": "loss", "value": 0.6599700596602633}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -1.5807592603191734, avg: 0.0850583475397993, max: 2.768745806515217
# {"metric": "q", "value": 0.0850583475397993}
# score: (min: 0.0, avg: 1.0, max: 3.0
# {"metric": "score", "value": 1.0}
# step: (min: 166, avg: 226.8, max: 329
# {"metric": "step", "value": 226.8}
# {"metric": "run", "value": 240}
# ----------------------------------------------------------------------------------------------------
# RUN =  240
# score: (min: 0.0, avg: 1.6, max: 7.0
# {"metric": "score", "value": 1.6}
# step: (min: 155, avg: 255.8, max: 581
# {"metric": "step", "value": 255.8}
# {"metric": "run", "value": 250}
# ----------------------------------------------------------------------------------------------------
# RUN =  250
# loss: (min: 0.0005237586447037756, avg: 0.7163503985929419, max: 4.0543365478515625
# {"metric": "loss", "value": 0.7163503985929419}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -1.5780816566571594, avg: 0.03317702410825528, max: 2.7289115918427704
# {"metric": "q", "value": 0.03317702410825528}
# score: (min: 0.0, avg: 2.2, max: 10.0
# {"metric": "score", "value": 2.2}
# step: (min: 147, avg: 277.6, max: 634
# {"metric": "step", "value": 277.6}
# {"metric": "run", "value": 260}
# ----------------------------------------------------------------------------------------------------
# RUN =  260
# loss: (min: 0.0012620590860024095, avg: 0.6741222629882395, max: 3.626967668533325
# {"metric": "loss", "value": 0.6741222629882395}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -1.579737607575953, avg: 0.13042048124039546, max: 2.7319128481298685
# {"metric": "q", "value": 0.13042048124039546}
# score: (min: 0.0, avg: 1.8, max: 7.0
# {"metric": "score", "value": 1.8}
# step: (min: 162, avg: 262.6, max: 436
# {"metric": "step", "value": 262.6}
# {"metric": "run", "value": 270}
# ----------------------------------------------------------------------------------------------------
# RUN =  270
# score: (min: 0.0, avg: 1.5, max: 3.0
# {"metric": "score", "value": 1.5}
# step: (min: 172, avg: 248.9, max: 331
# {"metric": "step", "value": 248.9}
# {"metric": "run", "value": 280}
# ----------------------------------------------------------------------------------------------------
# RUN =  280
# loss: (min: 0.0012330521130934358, avg: 0.7020532374271424, max: 4.044870376586914
# {"metric": "loss", "value": 0.7020532374271424}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -1.5913878411054612, avg: 0.04645507784742862, max: 2.721132274419069
# {"metric": "q", "value": 0.04645507784742862}
# score: (min: 0.0, avg: 1.4, max: 4.0
# {"metric": "score", "value": 1.4}
# step: (min: 159, avg: 247.4, max: 360
# {"metric": "step", "value": 247.4}
# {"metric": "run", "value": 290}
# ----------------------------------------------------------------------------------------------------
# RUN =  290
# loss: (min: 0.0029298821464180946, avg: 0.7316007094429806, max: 3.8078725337982178
# {"metric": "loss", "value": 0.7316007094429806}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -1.5835346891731024, avg: -0.04461255918323993, max: 2.7293423177301883
# {"metric": "q", "value": -0.04461255918323993}
# score: (min: 0.0, avg: 1.2, max: 3.0
# {"metric": "score", "value": 1.2}
# step: (min: 160, avg: 237.6, max: 306
# {"metric": "step", "value": 237.6}
# {"metric": "run", "value": 300}
# ----------------------------------------------------------------------------------------------------
# RUN =  300
# score: (min: 0.0, avg: 1.5, max: 4.0
# {"metric": "score", "value": 1.5}
# step: (min: 171, avg: 257.8, max: 371
# {"metric": "step", "value": 257.8}
# {"metric": "run", "value": 310}
# ----------------------------------------------------------------------------------------------------
# RUN =  310
# loss: (min: 0.0015433949884027243, avg: 0.5682180953864008, max: 4.374651908874512
# {"metric": "loss", "value": 0.5682180953864008}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -1.560021142065525, avg: 0.07259234352223576, max: 2.7081705858558416
# {"metric": "q", "value": 0.07259234352223576}
# score: (min: 0.0, avg: 1.2, max: 3.0
# {"metric": "score", "value": 1.2}
# step: (min: 161, avg: 235.2, max: 332
# {"metric": "step", "value": 235.2}
# {"metric": "run", "value": 320}
# ----------------------------------------------------------------------------------------------------
# RUN =  320
# {"metric": "epsilon", "value": 0.9682342352941838}
# {"metric": "total_step", "value": 80000}
# score: (min: 0.0, avg: 1.5, max: 4.0
# {"metric": "score", "value": 1.5}
# step: (min: 174, avg: 256.8, max: 402
# {"metric": "step", "value": 256.8}
# {"metric": "run", "value": 330}
# ----------------------------------------------------------------------------------------------------
# RUN =  330
# loss: (min: 0.0010602150578051805, avg: 0.35246708335436416, max: 3.6302247047424316
# {"metric": "loss", "value": 0.35246708335436416}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -1.5743452137708664, avg: -0.08882773758611948, max: 2.7120862267911434
# {"metric": "q", "value": -0.08882773758611948}
# score: (min: 0.0, avg: 1.5, max: 3.0
# {"metric": "score", "value": 1.5}
# step: (min: 170, avg: 255.4, max: 355
# {"metric": "step", "value": 255.4}
# {"metric": "run", "value": 340}
# ----------------------------------------------------------------------------------------------------
# RUN =  340
# loss: (min: 0.0008347694529220462, avg: 0.01000640726927668, max: 0.048448678106069565
# {"metric": "loss", "value": 0.01000640726927668}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.31910493757459335, avg: -0.09743275826272307, max: 0.05928736811387353
# {"metric": "q", "value": -0.09743275826272307}
# score: (min: 0.0, avg: 1.2, max: 2.0
# {"metric": "score", "value": 1.2}
# step: (min: 168, avg: 234.2, max: 298
# {"metric": "step", "value": 234.2}
# {"metric": "run", "value": 350}
# ----------------------------------------------------------------------------------------------------
# RUN =  350
# score: (min: 0.0, avg: 1.6, max: 4.0
# {"metric": "score", "value": 1.6}
# step: (min: 164, avg: 254.3, max: 402
# {"metric": "step", "value": 254.3}
# {"metric": "run", "value": 360}
# ----------------------------------------------------------------------------------------------------
# RUN =  360
# loss: (min: 0.0005202256725169718, avg: 0.009445355661213397, max: 0.1132938340306282
# {"metric": "loss", "value": 0.009445355661213397}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.2814420136017725, avg: -0.09508535733033321, max: 0.06859125067247078
# {"metric": "q", "value": -0.09508535733033321}
# score: (min: 0.0, avg: 1.6, max: 4.0
# {"metric": "score", "value": 1.6}
# step: (min: 160, avg: 259.8, max: 404
# {"metric": "step", "value": 259.8}
# {"metric": "run", "value": 370}
# ----------------------------------------------------------------------------------------------------
# RUN =  370
# loss: (min: 0.0008015414932742715, avg: 0.009258378393366002, max: 0.1135595291852951
# {"metric": "loss", "value": 0.009258378393366002}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.3347538844478549, avg: -0.09357396296265011, max: 0.07071100041503085
# {"metric": "q", "value": -0.09357396296265011}
# score: (min: 0.0, avg: 1.2, max: 2.0
# {"metric": "score", "value": 1.2}
# step: (min: 168, avg: 229.8, max: 292
# {"metric": "step", "value": 229.8}
# {"metric": "run", "value": 380}
# ----------------------------------------------------------------------------------------------------
# RUN =  380
# score: (min: 0.0, avg: 1.0, max: 3.0
# {"metric": "score", "value": 1.0}
# step: (min: 160, avg: 222.1, max: 349
# {"metric": "step", "value": 222.1}
# {"metric": "run", "value": 390}
# ----------------------------------------------------------------------------------------------------
# RUN =  390
# loss: (min: 0.00040827420889399946, avg: 0.00923848801056738, max: 0.13435176014900208
# {"metric": "loss", "value": 0.00923848801056738}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.2618859063775744, avg: -0.09108724005694792, max: 0.11582273750507739
# {"metric": "q", "value": -0.09108724005694792}
# score: (min: 0.0, avg: 1.4, max: 3.0
# {"metric": "score", "value": 1.4}
# step: (min: 159, avg: 251.2, max: 362
# {"metric": "step", "value": 251.2}
# {"metric": "run", "value": 400}
# ----------------------------------------------------------------------------------------------------
# RUN =  400
# score: (min: 0.0, avg: 0.9, max: 4.0
# {"metric": "score", "value": 0.9}
# step: (min: 159, avg: 219.3, max: 391
# {"metric": "step", "value": 219.3}
# {"metric": "run", "value": 410}
# ----------------------------------------------------------------------------------------------------
# RUN =  410
# loss: (min: 0.0007581468089483678, avg: 0.008815096129314042, max: 0.1362447291612625
# {"metric": "loss", "value": 0.008815096129314042}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.2948589145173901, avg: -0.09660363000274229, max: 0.12934010393044446
# {"metric": "q", "value": -0.09660363000274229}
# score: (min: 0.0, avg: 1.6, max: 3.0
# {"metric": "score", "value": 1.6}
# step: (min: 167, avg: 258.2, max: 346
# {"metric": "step", "value": 258.2}
# {"metric": "run", "value": 420}
# ----------------------------------------------------------------------------------------------------
# RUN =  420
# loss: (min: 0.0005008923471905291, avg: 0.008228608981880825, max: 0.044516172260046005
# {"metric": "loss", "value": 0.008228608981880825}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.2650190971023403, avg: -0.0905046692377588, max: 0.06888752250000835
# {"metric": "q", "value": -0.0905046692377588}
# score: (min: 0.0, avg: 2.0, max: 6.0
# {"metric": "score", "value": 2.0}
# step: (min: 169, avg: 270.6, max: 479
# {"metric": "step", "value": 270.6}
# {"metric": "run", "value": 430}
# ----------------------------------------------------------------------------------------------------
# RUN =  430
# score: (min: 0.0, avg: 1.1, max: 3.0
# {"metric": "score", "value": 1.1}
# step: (min: 165, avg: 230.2, max: 343
# {"metric": "step", "value": 230.2}
# {"metric": "run", "value": 440}
# ----------------------------------------------------------------------------------------------------
# RUN =  440
# loss: (min: 0.0004908737610094249, avg: 0.008199497510504443, max: 0.1156257763504982
# {"metric": "loss", "value": 0.008199497510504443}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.2831270493054763, avg: -0.09352856383333724, max: 0.060060709765239154
# {"metric": "q", "value": -0.09352856383333724}
# score: (min: 0.0, avg: 1.4, max: 2.0
# {"metric": "score", "value": 1.4}
# step: (min: 156, avg: 244.8, max: 300
# {"metric": "step", "value": 244.8}
# {"metric": "run", "value": 450}
# ----------------------------------------------------------------------------------------------------
# RUN =  450
# score: (min: 0.0, avg: 1.2, max: 4.0
# {"metric": "score", "value": 1.2}
# step: (min: 161, avg: 238.8, max: 414
# {"metric": "step", "value": 238.8}
# {"metric": "run", "value": 460}
# ----------------------------------------------------------------------------------------------------
# RUN =  460
# loss: (min: 0.0005981890135444701, avg: 0.00815105853305431, max: 0.12221604585647583
# {"metric": "loss", "value": 0.00815105853305431}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.2720529199484736, avg: -0.09611585600327657, max: 0.04007823879510397
# {"metric": "q", "value": -0.09611585600327657}
# score: (min: 0.0, avg: 0.8, max: 2.0
# {"metric": "score", "value": 0.8}
# step: (min: 165, avg: 212, max: 298
# {"metric": "step", "value": 212}
# {"metric": "run", "value": 470}
# ----------------------------------------------------------------------------------------------------
# RUN =  470
# loss: (min: 0.0004682148282881826, avg: 0.008367598473938415, max: 0.11695607751607895
# {"metric": "loss", "value": 0.008367598473938415}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.3002183513576165, avg: -0.09345165890865523, max: 0.10684591917932265
# {"metric": "q", "value": -0.09345165890865523}
# score: (min: 0.0, avg: 1.4, max: 6.0
# {"metric": "score", "value": 1.4}
# step: (min: 170, avg: 248.7, max: 434
# {"metric": "step", "value": 248.7}
# {"metric": "run", "value": 480}
# ----------------------------------------------------------------------------------------------------
# RUN =  480
# {"metric": "epsilon", "value": 0.9258812941178015}
# {"metric": "total_step", "value": 120000}
# score: (min: 0.0, avg: 1.2, max: 2.0
# {"metric": "score", "value": 1.2}
# step: (min: 160, avg: 233.4, max: 298
# {"metric": "step", "value": 233.4}
# {"metric": "run", "value": 490}
# ----------------------------------------------------------------------------------------------------
# RUN =  490
# loss: (min: 0.00036221134359948337, avg: 0.008154479247197742, max: 0.05008804425597191
# {"metric": "loss", "value": 0.008154479247197742}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.2532283929706318, avg: -0.07036002881814697, max: 0.05692531610111473
# {"metric": "q", "value": -0.07036002881814697}
# score: (min: 0.0, avg: 0.6, max: 3.0
# {"metric": "score", "value": 0.6}
# step: (min: 159, avg: 199.4, max: 331
# {"metric": "step", "value": 199.4}
# {"metric": "run", "value": 500}
# ----------------------------------------------------------------------------------------------------
# RUN =  500
# score: (min: 0.0, avg: 1.7, max: 6.0
# {"metric": "score", "value": 1.7}
# step: (min: 157, avg: 260.9, max: 474
# {"metric": "step", "value": 260.9}
# {"metric": "run", "value": 510}
# ----------------------------------------------------------------------------------------------------
# RUN =  510
# loss: (min: 0.00033249883563257754, avg: 0.008017665998806479, max: 0.039617061614990234
# {"metric": "loss", "value": 0.008017665998806479}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.15749302655614883, avg: -0.04948839779682858, max: 0.04485937347897561
# {"metric": "q", "value": -0.04948839779682858}
# score: (min: 1.0, avg: 2.3, max: 4.0
# {"metric": "score", "value": 2.3}
# step: (min: 202, avg: 287.6, max: 396
# {"metric": "step", "value": 287.6}
# {"metric": "run", "value": 520}
# ----------------------------------------------------------------------------------------------------
# RUN =  520
# loss: (min: 0.00043800807907246053, avg: 0.007567818297276972, max: 0.11275573819875717
# {"metric": "loss", "value": 0.007567818297276972}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.19790044239285634, avg: -0.047500215456093425, max: 0.09886318790900987
# {"metric": "q", "value": -0.047500215456093425}
# score: (min: 0.0, avg: 1.2, max: 3.0
# {"metric": "score", "value": 1.2}
# step: (min: 162, avg: 235.4, max: 357
# {"metric": "step", "value": 235.4}
# {"metric": "run", "value": 530}
# ----------------------------------------------------------------------------------------------------
# RUN =  530
# score: (min: 0.0, avg: 1.2, max: 5.0
# {"metric": "score", "value": 1.2}
# step: (min: 166, avg: 241.9, max: 473
# {"metric": "step", "value": 241.9}
# {"metric": "run", "value": 540}
# ----------------------------------------------------------------------------------------------------
# RUN =  540
# loss: (min: 0.00029593490762636065, avg: 0.007868764896848006, max: 0.11167705059051514
# {"metric": "loss", "value": 0.007868764896848006}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.19040275114006364, avg: -0.04749042757712436, max: 0.14084701404528457
# {"metric": "q", "value": -0.04749042757712436}
# score: (min: 0.0, avg: 1.3, max: 3.0
# {"metric": "score", "value": 1.3}
# step: (min: 156, avg: 227.3, max: 280
# {"metric": "step", "value": 227.3}
# {"metric": "run", "value": 550}
# ----------------------------------------------------------------------------------------------------
# RUN =  550
# score: (min: 0.0, avg: 1.5, max: 5.0
# {"metric": "score", "value": 1.5}
# step: (min: 163, avg: 249, max: 443
# {"metric": "step", "value": 249}
# {"metric": "run", "value": 560}
# ----------------------------------------------------------------------------------------------------
# RUN =  560
# loss: (min: 0.00027757277712225914, avg: 0.007830767109961017, max: 0.11658154428005219
# {"metric": "loss", "value": 0.007830767109961017}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.17357200250437016, avg: -0.046949153596458744, max: 0.0826603321635048
# {"metric": "q", "value": -0.046949153596458744}
# score: (min: 0.0, avg: 1.8, max: 4.0
# {"metric": "score", "value": 1.8}
# step: (min: 167, avg: 271.9, max: 391
# {"metric": "step", "value": 271.9}
# {"metric": "run", "value": 570}
# ----------------------------------------------------------------------------------------------------
# RUN =  570
# loss: (min: 0.00033369005541317165, avg: 0.008082957961742068, max: 0.11941168457269669
# {"metric": "loss", "value": 0.008082957961742068}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.15812853829411325, avg: -0.0455948417781711, max: 0.10792943693464623
# {"metric": "q", "value": -0.0455948417781711}
# score: (min: 0.0, avg: 1.2, max: 4.0
# {"metric": "score", "value": 1.2}
# step: (min: 159, avg: 240.1, max: 372
# {"metric": "step", "value": 240.1}
# {"metric": "run", "value": 580}
# ----------------------------------------------------------------------------------------------------
# RUN =  580
# score: (min: 0.0, avg: 1.3, max: 2.0
# {"metric": "score", "value": 1.3}
# step: (min: 170, avg: 243.6, max: 299
# {"metric": "step", "value": 243.6}
# {"metric": "run", "value": 590}
# ----------------------------------------------------------------------------------------------------
# RUN =  590
# loss: (min: 0.00016576764755882323, avg: 0.00742964183317963, max: 0.11603011190891266
# {"metric": "loss", "value": 0.00742964183317963}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.1543915517104324, avg: -0.04405068916176198, max: 0.07936755130183883
# {"metric": "q", "value": -0.04405068916176198}
# score: (min: 0.0, avg: 1.4, max: 5.0
# {"metric": "score", "value": 1.4}
# step: (min: 160, avg: 247.6, max: 467
# {"metric": "step", "value": 247.6}
# {"metric": "run", "value": 600}
# ----------------------------------------------------------------------------------------------------
# RUN =  600
# score: (min: 0.0, avg: 1.0, max: 3.0
# {"metric": "score", "value": 1.0}
# step: (min: 158, avg: 223.5, max: 343
# {"metric": "step", "value": 223.5}
# {"metric": "run", "value": 610}
# ----------------------------------------------------------------------------------------------------
# RUN =  610
# loss: (min: 0.00027906574541702867, avg: 0.007286690871755127, max: 0.04160253703594208
# {"metric": "loss", "value": 0.007286690871755127}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.15557032795652048, avg: -0.04228137176761476, max: 0.06659421858727001
# {"metric": "q", "value": -0.04228137176761476}
# score: (min: 0.0, avg: 0.9, max: 3.0
# {"metric": "score", "value": 0.9}
# step: (min: 159, avg: 227.2, max: 363
# {"metric": "step", "value": 227.2}
# {"metric": "run", "value": 620}
# ----------------------------------------------------------------------------------------------------
# RUN =  620
# loss: (min: 0.00026850865106098354, avg: 0.007309889357042266, max: 0.041732531040906906
# {"metric": "loss", "value": 0.007309889357042266}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.15670398780726827, avg: -0.04476257874786024, max: 0.09274124867428328
# {"metric": "q", "value": -0.04476257874786024}
# score: (min: 0.0, avg: 1.3, max: 3.0
# {"metric": "score", "value": 1.3}
# step: (min: 165, avg: 240.5, max: 345
# {"metric": "step", "value": 240.5}
# {"metric": "run", "value": 630}
# ----------------------------------------------------------------------------------------------------
# RUN =  630
# score: (min: 0.0, avg: 1.3, max: 4.0
# {"metric": "score", "value": 1.3}
# step: (min: 160, avg: 234.6, max: 398
# {"metric": "step", "value": 234.6}
# {"metric": "run", "value": 640}
# ----------------------------------------------------------------------------------------------------
# RUN =  640
# loss: (min: 0.0002222450711997226, avg: 0.007353605511700153, max: 0.04918539896607399
# {"metric": "loss", "value": 0.007353605511700153}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.1756768642453244, avg: -0.04356487055120473, max: 0.08361421162990154
# {"metric": "q", "value": -0.04356487055120473}
# score: (min: 0.0, avg: 1.4, max: 4.0
# {"metric": "score", "value": 1.4}
# step: (min: 161, avg: 246.6, max: 386
# {"metric": "step", "value": 246.6}
# {"metric": "run", "value": 650}
# ----------------------------------------------------------------------------------------------------
# RUN =  650
# {"metric": "epsilon", "value": 0.8835283529414192}
# {"metric": "total_step", "value": 160000}
# score: (min: 0.0, avg: 1.0, max: 3.0
# {"metric": "score", "value": 1.0}
# step: (min: 161, avg: 226.5, max: 337
# {"metric": "step", "value": 226.5}
# {"metric": "run", "value": 660}
# ----------------------------------------------------------------------------------------------------
# RUN =  660
# loss: (min: 0.0002129900676663965, avg: 0.005730572505490273, max: 0.0624878816306591
# {"metric": "loss", "value": 0.005730572505490273}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.16973670154548018, avg: -0.019853305064610614, max: 0.12015505719813518
# {"metric": "q", "value": -0.019853305064610614}
# score: (min: 0.0, avg: 0.9, max: 3.0
# {"metric": "score", "value": 0.9}
# step: (min: 160, avg: 216.6, max: 318
# {"metric": "step", "value": 216.6}
# {"metric": "run", "value": 670}
# ----------------------------------------------------------------------------------------------------
# RUN =  670
# score: (min: 0.0, avg: 1.0, max: 3.0
# {"metric": "score", "value": 1.0}
# step: (min: 157, avg: 216.6, max: 307
# {"metric": "step", "value": 216.6}
# {"metric": "run", "value": 680}
# ----------------------------------------------------------------------------------------------------
# RUN =  680
# loss: (min: 0.00018790025205817074, avg: 0.004443261436361354, max: 0.051775507628917694
# {"metric": "loss", "value": 0.004443261436361354}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.06341825383133255, avg: 0.006028112965517648, max: 0.0970231242274167
# {"metric": "q", "value": 0.006028112965517648}
# score: (min: 0.0, avg: 1.4, max: 4.0
# {"metric": "score", "value": 1.4}
# step: (min: 157, avg: 249.5, max: 377
# {"metric": "step", "value": 249.5}
# {"metric": "run", "value": 690}
# ----------------------------------------------------------------------------------------------------
# RUN =  690
# loss: (min: 0.00020754456636495888, avg: 0.00458456420811126, max: 0.11119285225868225
# {"metric": "loss", "value": 0.00458456420811126}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.054496673258836385, avg: 0.006285432012719976, max: 0.1178374123823596
# {"metric": "q", "value": 0.006285432012719976}
# score: (min: 0.0, avg: 2.4, max: 7.0
# {"metric": "score", "value": 2.4}
# step: (min: 162, avg: 305.8, max: 554
# {"metric": "step", "value": 305.8}
# {"metric": "run", "value": 700}
# ----------------------------------------------------------------------------------------------------
# RUN =  700
# loss: (min: 0.00019721014541573822, avg: 0.004420930530541227, max: 0.11007998883724213
# {"metric": "loss", "value": 0.004420930530541227}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.06352247529022861, avg: 0.006504351662184272, max: 0.16094627568032593
# {"metric": "q", "value": 0.006504351662184272}
# score: (min: 0.0, avg: 1.6, max: 4.0
# {"metric": "score", "value": 1.6}
# step: (min: 164, avg: 257.2, max: 373
# {"metric": "step", "value": 257.2}
# {"metric": "run", "value": 710}
# ----------------------------------------------------------------------------------------------------
# RUN =  710
# score: (min: 0.0, avg: 1.8, max: 4.0
# {"metric": "score", "value": 1.8}
# step: (min: 161, avg: 260.8, max: 380
# {"metric": "step", "value": 260.8}
# {"metric": "run", "value": 720}
# ----------------------------------------------------------------------------------------------------
# RUN =  720
# loss: (min: 0.0001555415365146473, avg: 0.004341089691632078, max: 0.12050127983093262
# {"metric": "loss", "value": 0.004341089691632078}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.06784843130386434, avg: 0.006675210256156134, max: 0.15059518637193833
# {"metric": "q", "value": 0.006675210256156134}
# score: (min: 0.0, avg: 1.4, max: 4.0
# {"metric": "score", "value": 1.4}
# step: (min: 165, avg: 246.8, max: 397
# {"metric": "step", "value": 246.8}
# {"metric": "run", "value": 730}
# ----------------------------------------------------------------------------------------------------
# RUN =  730
# score: (min: 0.0, avg: 1.5, max: 3.0
# {"metric": "score", "value": 1.5}
# step: (min: 161, avg: 244.6, max: 336
# {"metric": "step", "value": 244.6}
# {"metric": "run", "value": 740}
# ----------------------------------------------------------------------------------------------------
# RUN =  740
# loss: (min: 0.00020375914755277336, avg: 0.004359277443145401, max: 0.1209867000579834
# {"metric": "loss", "value": 0.004359277443145401}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.05925618739973288, avg: 0.008029191740649767, max: 0.1662434848997509
# {"metric": "q", "value": 0.008029191740649767}
# score: (min: 0.0, avg: 0.9, max: 3.0
# {"metric": "score", "value": 0.9}
# step: (min: 169, avg: 220.9, max: 339
# {"metric": "step", "value": 220.9}
# {"metric": "run", "value": 750}
# ----------------------------------------------------------------------------------------------------
# RUN =  750
# loss: (min: 0.00012615110608749092, avg: 0.004130822925537359, max: 0.04071273282170296
# {"metric": "loss", "value": 0.004130822925537359}
# accuracy: (min: 0, avg: 0, max: 0
# {"metric": "accuracy", "value": 0}
# q: (min: -0.06752449668827466, avg: 0.00881082796275965, max: 0.09984852460504044
# {"metric": "q", "value": 0.00881082796275965}
# score: (min: 1.0, avg: 1.9, max: 3.0
# {"metric": "score", "value": 1.9}
# step: (min: 211, avg: 279.2, max: 358
# {"metric": "step", "value": 279.2}
# {"metric": "run", "value": 760}
# ----------------------------------------------------------------------------------------------------
# RUN =  760
